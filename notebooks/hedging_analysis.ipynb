# %% [markdown]
# *Continuous Ideal Hedge Simulation and Non-Constant assumptions (Dynamic yield, Non-Constant Risk Free).*

# %% [markdown]
# The subsequent steps will outline adding continuous dividend yields (q) to Black-Scholes and evaluating continuous hedging.

# %% [markdown]
# *Added VaR / CVaR metrics and explicit baseline strategy comparisons.*

# %% [markdown]
# # Hedging Analysis
#
# This notebook runs the project baseline and produces summary tables and figures for the report.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.experiments import ExperimentConfig, run_experiment, save_plots, save_summary_table

# %%
config = ExperimentConfig(
    ticker='SPY',
    start='2020-01-01',
    end='2024-12-31',
    maturity_days=21,
    fixed_volatility=0.20,
    rate=0.02,
    use_realized_vol=False,
    transaction_cost_bps=5.0,
    rehedge_frequencies=(1, 2, 5),
)

# %%
results, summary = run_experiment(config)
summary

# %%
save_plots(results)
save_summary_table(summary)

# %%
strategy_name = list(results.keys())[0]
results[strategy_name].head()

# %%
results[strategy_name][[
    'spot', 'option_price', 'delta', 'gamma', 'theta', 'vega', 'rho',
    'portfolio_value', 'hedge_error', 'gamma_pnl_approx', 'theta_pnl_approx',
    'vega_pnl_approx', 'rho_pnl_approx', 'pnl_attribution_residual'
]].tail(10)
